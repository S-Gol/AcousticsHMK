# %% [markdown]
# Acoustics HMK 4
#
# 10.1, 10.3, 10.5, 10.7, 10.8, 10.17, 12.3, 12.5, 12.6

# %% [markdown]
# 10.1
#
# Find
#
# - acoustic density
# - acoustic particle velocity, v
# - kinetic energy density
# - potential energy density
# - time-averaged intensity
#
# for $p=\mathbf{Re} (\hat{p}e^{j(\omega t -kx)})$

# %% [markdown]
# - $\rho_1=\frac{p(x,t)}{c^2}$
# - $v_1=\frac{p(x,t)}{\pm \rho_m c}$
# - $KE = \frac{1}{2}\rho_mv_1^2$
# - $PE = \frac{1}{2}\frac{\rho_1^2}{\rho_m c^2}$
# - $I=\frac{p_1^2}{2\rho_m c}=\frac{p_{rms}^2}{\rho_m c}$

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# 10.17
#
# Tweeter horn. A commercial horn with a 100 (2.5 cm) diameter throat is 1000 (25 cm) long and
# opens to a bell with a diameter of 400 (10 cm).
#
# - Flare constant. If the horn has a cross-sectional area that grows exponentially, determine the flare constant, h.
# - Cut-off frequency. If the horn were infinitely long, what would be its cut-off frequency?

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# 12.5

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)
